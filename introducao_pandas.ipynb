# %% [markdown]
# #Atividade01 - Aprendizado de Máquina

# %% [markdown]
# Aluno: Alan Nascimento Gomes

# %%
import pandas as pd

# %% [markdown]
# Questão 1

# %%
df = pd.read_csv("heart.csv")

# %% [markdown]
# Questão 2

# %%
df.head(20)

# %% [markdown]
# Questão 3

# %%
df['age'].count()

# %% [markdown]
# Questão 4

# %%
print("Média: ", df["age"].mean())
print("Desvio Padrão: ", df["age"].std())
print("Valor Mínimo: ", df["age"].min())
print("Valor Máximo: ", df["age"].max())

# %% [markdown]
# Questão 5

# %%
df.sort_values('age', ascending = False ).head(5)

# %% [markdown]
# # Entendendo o funcionamento do kNN

# %% [markdown]
# ## Importação de módulos do Python

# %%
import numpy as np

# %% [markdown]
# ## Montando o dataset

# %%
ds = np.array([[ 25 , 40000, 135 ],# 0
               [ 35,  60000, 256], # 1 
               [ 45,  80000, 231], # 2
               [ 20,  20000, 267], # 3
               [ 35,  120000, 139],# 4
               [ 52,  18000, 150], # 5
               [ 23,  95000, 127], # 6
               [ 40,  62000, 216], # 7
               [ 60,  100000, 139],# 8
               [ 48, 220000, 250], # 9
               [ 33,  150000, 264]])# 10

# %% [markdown]
# # Definindo X e y

# %%
X_treino = ds[:,0:2]
y_treino = ds[:, 2]

# %% [markdown]
# Questão 1 - Altere nossa implementação de kNN para que ela possa calcular regressão. Dica: crie uma função predict_regression baseada na função predict_classification do documento notebook 02-Aula kNN.ipynb.

# %%
def euclidean_distances(X, X_row):
    X_ = (X - X_row) ** 2
    return np.sum(X_, axis=1) ** 0.5

# %%
def get_neighbors(X_train, test_row, k):
    distances = euclidean_distances(X_train, test_row)
    idx_sort = np.argsort(distances)
    return idx_sort[:k]

# %%
def predict_regression(X, y, test_row, k):
    idx_sort = get_neighbors(X, test_row, k)
    output_values = y[idx_sort] 
    counts = np.unique(output_values, return_counts=True)
    regression = counts[0].mean()
    # print('idx_sort:{}, output_values:{}, prediction:{}'.format(idx_sort, output_values, regression))
    return regression

# %% [markdown]
# Questão 2 - (a)

# %%
rot1 = predict_regression(X_treino, y_treino, np.array([42, 142000]), 1)
print('Valor: ', rot1)
# Out:
# Valor:  264.0

# %% [markdown]
# Questão 2 - (b)

# %%
rot2 = predict_regression(X_treino, y_treino, np.array([30, 50000]), 1)
print('Valor: ', rot2)
# Out:
# Valor:  135.0

# %% [markdown]
# ## Comparando com a biblioteca Scikit-Learn

# %%
from sklearn.neighbors import KNeighborsRegressor

neigh = KNeighborsRegressor(n_neighbors=1)
neigh.fit(X_treino, y_treino)
neigh.predict(np.array([[42, 142000]]))
# Out:
# array([264.])

# %%
neigh = KNeighborsRegressor(n_neighbors=1)
neigh.fit(X_treino, y_treino)
neigh.predict(np.array([[30, 50000]]))
# Out:
# array([135.])
